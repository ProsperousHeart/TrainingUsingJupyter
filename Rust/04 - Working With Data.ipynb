# %% [markdown]
# # [Enums](https://academy.zerotomastery.io/courses/1363752/lectures/31679673)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# When matching an **enum** must use `::` and then one of it's variants, followed by the fat arrow & what to do.
#
# match requires all possibilities to be verified
#
# ![image-4.png](attachment:image-4.png)
#
# that way you can pass in enumerations instead of just numbers and strings

# %% [markdown]
# # [Demo:  Enums](https://academy.zerotomastery.io/courses/1363752/lectures/31612454)
#
# **enum** is created outside of main function
#
# ![image.png](attachment:image.png)
#
# If you change your **enum** but not your match, you will get an error.
#
# ![image-2.png](attachment:image-2.png)
#
# compiler helps you by giving direction to check

# %% [markdown]
# # [Activity a7: Enums](https://academy.zerotomastery.io/courses/1363752/lectures/31360854)
#
# **enums** are used to create your own type in Rust & provide increase code robustness as well as make your code easier to read.
#
# ![image.png](attachment:image.png)
#
# You put the type in - for thsi example it is `Colors` type.
#
# ![image-2.png](attachment:image-2.png)
#
# Compile & run you may see errors, like this:
#
# ![image-3.png](attachment:image-3.png)
#
# but it just means that not all of them were utilized.
#
# Rust tells you what is wrong or could be wrong upon compiling!

# %% [markdown]
# # [Structs](https://academy.zerotomastery.io/courses/1363752/lectures/31679718)
#
# Allows you to create a data type that contains multiple pieces of data
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # [Demo: Struct](https://academy.zerotomastery.io/courses/1363752/lectures/31670384)
#
# `f64` type is a 64 bit floating point (double) number.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # [Activity: a8 - struct](https://academy.zerotomastery.io/courses/1363752/lectures/31551267)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # [Tuples](https://academy.zerotomastery.io/courses/1363752/lectures/31679799)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# destructuring - like python unpacking!
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# if more than 2 or 3 fields, **struct** will help keep you more organized.

# %% [markdown]
# # [Demo:  Tuples](https://academy.zerotomastery.io/courses/1363752/lectures/31670603)
#
# create artesian coordinate
#
# ![image.png](attachment:image.png)
#
# good to destructure ...
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# better to create a structure because numbers can be ambiguous ... keep tuples at 3 max (suggested)

# %% [markdown]
# # [Activity a9: Tuples](https://academy.zerotomastery.io/courses/1363752/lectures/31553733)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # [Expressions](https://academy.zerotomastery.io/courses/1363752/lectures/31679825)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# you set the evaluation of the expression here:
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# you can nest evaluations! This had a really large let binding and assignment to value of multiple expressions.
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# # [Demo: Expressions](https://academy.zerotomastery.io/courses/1363752/lectures/31609783)
