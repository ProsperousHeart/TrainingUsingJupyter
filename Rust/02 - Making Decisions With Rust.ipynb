# %% [markdown]
# # [Control Flow: If & Else](https://academy.zerotomastery.io/courses/1363752/lectures/31360424)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # [Activity3a:  Control Flow With IF & Else](https://academy.zerotomastery.io/courses/1363752/lectures/31361122)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # [Activity 3b:  control flow with if/else](https://academy.zerotomastery.io/courses/1363752/lectures/31360439)
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # [Match Expression](https://academy.zerotomastery.io/courses/1363752/lectures/31360452)
#
# MAthc expressions are similar to if-else statements
#
# ![image.png](attachment:image.png)
#
# match muct be exhaustiv - eve example
#
# ![image-2.png](attachment:image-2.png)
#
# Requires a fat arrow and an expression to evaluate. USes a comma, not aemicolon because match works on expressions not statements.
#
# ![image-3.png](attachment:image-3.png)
#
# The `_` is everything else!
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# # [DEMO:  Basic Match](https://academy.zerotomastery.io/courses/1363752/lectures/31360455)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Activity 4a:  Basic Match 1
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # [Activity 4b: Basic MAtch 2](https://academy.zerotomastery.io/courses/1363752/lectures/31360522)
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
